# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import mglearn
mpl.rcParams.update({
    "figure.facecolor":"black",
    "axes.facecolor":"black",
    "axes.edgecolor":"orange",
    "xtick.color":"red",
    "ytick.color":"yellow",
    "legend.labelcolor":"linecolor"
    
})
plt.plot(range(10))
X, y=mglearn.datasets.load_extended_boston()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, random_state=0)

from sklearn.linear_model import Ridge
ridge=Ridge().fit(X_train, y_train)

# %%
print("Training set score: {}".format(ridge.score(X_train, y_train)))
print("\nTesting set score: {}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score: 0.8857966585170941
#
# Testing set score: 0.7527683481744758

# %%
# If we are interested in Generalisation we;ll be using Ridge as it's more restrirted model than ridge
