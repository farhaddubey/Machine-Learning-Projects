# %%
# Regression is used to find the relationship between variables
# Linear Regression draws a straight line
import matplotlib.pyplot as plt
x=[5, 7, 8, 7, 2, 17,2,  9, 4, 11, 12, 9, 6]
y=[99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
# For the graph to be plotted x & y must be equal in nos
plt.scatter(x, y)
plt.show()

# %%
from scipy import stats
x=[5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y=[99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
    return slope*x+intercept
mymodel =list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats
x =[5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y=[99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
slope, intercept, r, p, std_err = stats.linregress(x, y)
len(x)==len(y)
def myfunc(x):
    return slope*x + intercept
# Now the fucntion will return a new value for the y=axis of x array
mymodel_arr_y=list(map(myfunc, x))
print("The newly geneated array in mymodel_arr is: \n{}".format(mymodel_arr_y))
# map(iterator) iterates over the values of x runs the myfunc function for each value & gets a return; all thhe return are then 
# converted into list by usage of the list function & the list is assigned to variable mymodel
# New values of x is assigned to mymodel
plt.scatter(x, y)
plt.plot(x, mymodel_arr_y)
# For both the above func the no. of points in x & y must be same
plt.show()
# Out:
# The newly geneated array in mymodel_arr is:
# [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]

# %%
# r for relationship: r ranges form -1 to 1 if r==0: no relationship else if(1/ -1): 100% relationship
# Python & Scipy module will compute that value for me

# %%
from scipy import stats
x=[5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y=[99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
slope, intercept, r, p, std_err = stats.linregress(x, y)
# p is just like ALPHA which signifies the strenth of 0
# lesser p indicates strong evidence against the null hypothesis
# Latge p indicates weak evidence against the null hypothesis
print(r)
# Out:
# -0.758591524376155

# %%
# The result -.76 indicates that there's a relationship, not perfect, it indicates that here in future prediction 
# linear regression 
# can be used

# %%
speed = myfunc(10)
speed
# Out:
# 85.59308314937454

# %% [raw]
# r

# %%
print(r)
# Out:
# -0.758591524376155

# %%
# Now let's check a condition of bad fitting
x = [89, 43, 36, 36, 95, 10, 66, 34, 38, 20, 26, 29, 48, 64, 6, 5, 36, 66, 72, 40]
y = [21, 46, 3, 35, 67, 95, 53, 72, 58, 10, 26, 34, 90, 33, 38, 20, 56, 2, 47, 15]
from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(x, y)
print("Correlation factor r is: {}".format(r))
# Out:
# Correlation factor r is: 0.01331814154297491

# %%
# As the r is very low, We will be getting a bad prediction
# Let's check
mymodel_list_y=list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel_list_y)
plt.show()
