# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("A:/Machine Learning/loan_data_set.csv")
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
dataset.isnull().sum()
# returns the count of null values in each row
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Finding the no. of percentage null value
(dataset.isnull().sum()/dataset.isnull().count())*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
# Finding the total null values in data
dataset.isnull().sum().sum()
# Out:
# 149

# %%
# Finding the non null datas in dataset
dataset.notnull().sum().sum()
# Out:
# 7833

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams.update({
    "figure.facecolor":"black",
    "figure.edgecolor":"orange",
    "axes.facecolor":"black",
    "axes.edgecolor":"green",
    "xtick.color":"yellow",
    "ytick.color":"blue",
    "legend.labelcolor":"linecolor"
})

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# White part represents Null values and black portion represents not null value

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 149

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dataset=dataset.drop(columns=["Credit_History", "Self_Employed"])

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dataset.shape
# Out:
# (614, 11)

# %%
dataset.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education  ApplicantIncome  \
# 0  LP001002   Male      No          0      Graduate             5849
# 1  LP001003   Male     Yes          1      Graduate             4583
# 2  LP001005   Male     Yes          0      Graduate             3000
# 3  LP001006   Male     Yes          0  Not Graduate             2583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 0                0.0         NaN             360.0         Urban           Y
# 1             1508.0       128.0             360.0         Rural           N
# 2                0.0        66.0             360.0         Urban           Y
# 3             2358.0       120.0             360.0         Urban           Y

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education  ApplicantIncome  \
# 1    LP001003    Male     Yes          1      Graduate             4583
# 2    LP001005    Male     Yes          0      Graduate             3000
# 3    LP001006    Male     Yes          0  Not Graduate             2583
# 4    LP001008    Male      No          0      Graduate             6000
# 5    LP001011    Male     Yes          2      Graduate             5417
# ..        ...     ...     ...        ...           ...              ...
# 609  LP002978  Female      No          0      Graduate             2900
# 610  LP002979    Male     Yes         3+      Graduate             4106
# 611  LP002983    Male     Yes          1      Graduate             8072
# 612  LP002984    Male     Yes          2      Graduate             7583
# 613  LP002990  Female      No          0      Graduate             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553 entries, 1 to 613
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            553 non-null    object
#  1   Gender             553 non-null    object
#  2   Married            553 non-null    object
#  3   Dependents         553 non-null    object
#  4   Education          553 non-null    object
#  5   ApplicantIncome    553 non-null    int64
#  6   CoapplicantIncome  553 non-null    float64
#  7   LoanAmount         553 non-null    float64
#  8   Loan_Amount_Term   553 non-null    float64
#  9   Property_Area      553 non-null    object
#  10  Loan_Status        553 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 51.8+ KB

# %%
dataset.fillna(method="ffill")
# dataset.fillna(method="bfill")
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education  ApplicantIncome  \
# 1    LP001003    Male     Yes          1      Graduate             4583
# 2    LP001005    Male     Yes          0      Graduate             3000
# 3    LP001006    Male     Yes          0  Not Graduate             2583
# 4    LP001008    Male      No          0      Graduate             6000
# 5    LP001011    Male     Yes          2      Graduate             5417
# ..        ...     ...     ...        ...           ...              ...
# 609  LP002978  Female      No          0      Graduate             2900
# 610  LP002979    Male     Yes         3+      Graduate             4106
# 611  LP002983    Male     Yes          1      Graduate             8072
# 612  LP002984    Male     Yes          2      Graduate             7583
# 613  LP002990  Female      No          0      Graduate             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# ...

# %%
dataset.fillna(method="bfill", axis=1)
# Out:
#       Loan_ID  Gender Married Dependents     Education ApplicantIncome  \
# 1    LP001003    Male     Yes          1      Graduate            4583
# 2    LP001005    Male     Yes          0      Graduate            3000
# 3    LP001006    Male     Yes          0  Not Graduate            2583
# 4    LP001008    Male      No          0      Graduate            6000
# 5    LP001011    Male     Yes          2      Graduate            5417
# ..        ...     ...     ...        ...           ...             ...
# 609  LP002978  Female      No          0      Graduate            2900
# 610  LP002979    Male     Yes         3+      Graduate            4106
# 611  LP002983    Male     Yes          1      Graduate            8072
# 612  LP002984    Male     Yes          2      Graduate            7583
# 613  LP002990  Female      No          0      Graduate            4583
#
#     CoapplicantIncome LoanAmount Loan_Amount_Term Property_Area Loan_Status
# ...
